# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('capture20110810.binetflow')

# %%
data.shape
# Out:
# (2824636, 15)

# %%
data.head()
# Out:
#                     StartTime       Dur Proto        SrcAddr Sport    Dir  \
# 0  2011/08/10 09:46:59.607825  1.026539   tcp  94.44.127.113  1577     ->
# 1  2011/08/10 09:47:00.634364  1.009595   tcp  94.44.127.113  1577     ->
# 2  2011/08/10 09:47:48.185538  3.056586   tcp   147.32.86.89  4768     ->
# 3  2011/08/10 09:47:48.230897  3.111769   tcp   147.32.86.89  4788     ->
# 4  2011/08/10 09:47:48.963351  3.083411   tcp   147.32.86.89  4850     ->
#
#         DstAddr Dport State  sTos  dTos  TotPkts  TotBytes  SrcBytes  \
# 0  147.32.84.59  6881  S_RA   0.0   0.0        4       276       156
# 1  147.32.84.59  6881  S_RA   0.0   0.0        4       276       156
# 2   77.75.73.33    80  SR_A   0.0   0.0        3       182       122
# 3   77.75.73.33    80  SR_A   0.0   0.0        3       182       122
# 4   77.75.73.33    80  SR_A   0.0   0.0        3       182       122
#
#                                     Label
# 0  flow=Background-Established-cmpgw-CVUT
# ...

# %%
data['Is it Botnet?']=data.Label.str.contains('Botnet')

# %%
data.head()
# Out:
#                     StartTime       Dur Proto        SrcAddr Sport    Dir  \
# 0  2011/08/10 09:46:59.607825  1.026539   tcp  94.44.127.113  1577     ->
# 1  2011/08/10 09:47:00.634364  1.009595   tcp  94.44.127.113  1577     ->
# 2  2011/08/10 09:47:48.185538  3.056586   tcp   147.32.86.89  4768     ->
# 3  2011/08/10 09:47:48.230897  3.111769   tcp   147.32.86.89  4788     ->
# 4  2011/08/10 09:47:48.963351  3.083411   tcp   147.32.86.89  4850     ->
#
#         DstAddr Dport State  sTos  dTos  TotPkts  TotBytes  SrcBytes  \
# 0  147.32.84.59  6881  S_RA   0.0   0.0        4       276       156
# 1  147.32.84.59  6881  S_RA   0.0   0.0        4       276       156
# 2   77.75.73.33    80  SR_A   0.0   0.0        3       182       122
# 3   77.75.73.33    80  SR_A   0.0   0.0        3       182       122
# 4   77.75.73.33    80  SR_A   0.0   0.0        3       182       122
#
#                                     Label  Is it Botnet?
# ...

# %%
botnetdata=data[data.Label.str.contains('Botnet')]
botnetdata.head()
# Out:
#                          StartTime          Dur Proto        SrcAddr Sport  \
# 675613  2011/08/10 11:04:24.863449     0.000278   udp  147.32.84.165  1025
# 675948  2011/08/10 11:04:27.118993     0.020525   udp  147.32.84.165  1025
# 675953  2011/08/10 11:04:27.140727     0.045125   tcp  147.32.84.165  1027
# 690001  2011/08/10 11:06:23.268442     0.336250   udp  147.32.84.165  1025
# 690036  2011/08/10 11:06:23.606888  3514.083496   tcp  147.32.84.165  1039
#
#           Dir         DstAddr  Dport     State  sTos  dTos  TotPkts  TotBytes  \
# 675613    <->     147.32.80.9     53       CON   0.0   0.0        2       203
# 675948    <->     147.32.80.9     53       CON   0.0   0.0        2       590
# 675953     ->  74.125.232.195     80  SRPA_SPA   0.0   0.0        7       882
# 690001    <->     147.32.80.9     53       CON   0.0   0.0        2       215
# 690036     ->  60.190.222.139  65520   SPA_SPA   0.0   0.0      120      7767
#
# ...

# %%
normaldata=data[data.Label.str.contains('Normal')]
normaldata.head()
# Out:
#                       StartTime       Dur Proto        SrcAddr  Sport    Dir  \
# 150  2011/08/10 09:46:53.160043  0.000000   udp    147.32.80.9     53     ->
# 408  2011/08/10 09:46:54.045343  0.000000   udp    147.32.80.9     53     ->
# 495  2011/08/10 09:46:54.460552  0.000000   udp    147.32.80.9     53     ->
# 596  2011/08/10 09:46:54.779125  0.000291   udp  147.32.84.134  40693    <->
# 597  2011/08/10 09:46:54.779641  0.000321   udp  147.32.84.134  47415    <->
#
#            DstAddr  Dport State  sTos  dTos  TotPkts  TotBytes  SrcBytes  \
# 150  147.32.86.111  54230   INT   0.0   NaN        1       141       141
# 408  147.32.86.111  58314   INT   0.0   NaN        1       247       247
# 495  147.32.86.111  54823   INT   0.0   NaN        1       173       173
# 596    147.32.80.9     53   CON   0.0   0.0        2       207        72
# 597    147.32.80.9     53   CON   0.0   0.0        2       247        72
#
#                                         Label  Is it Botnet?
# ...

# %%
bgdata=data[data.Label.str.contains('Background')]
bgdata.head()
# Out:
#                     StartTime       Dur Proto        SrcAddr Sport    Dir  \
# 0  2011/08/10 09:46:59.607825  1.026539   tcp  94.44.127.113  1577     ->
# 1  2011/08/10 09:47:00.634364  1.009595   tcp  94.44.127.113  1577     ->
# 2  2011/08/10 09:47:48.185538  3.056586   tcp   147.32.86.89  4768     ->
# 3  2011/08/10 09:47:48.230897  3.111769   tcp   147.32.86.89  4788     ->
# 4  2011/08/10 09:47:48.963351  3.083411   tcp   147.32.86.89  4850     ->
#
#         DstAddr Dport State  sTos  dTos  TotPkts  TotBytes  SrcBytes  \
# 0  147.32.84.59  6881  S_RA   0.0   0.0        4       276       156
# 1  147.32.84.59  6881  S_RA   0.0   0.0        4       276       156
# 2   77.75.73.33    80  SR_A   0.0   0.0        3       182       122
# 3   77.75.73.33    80  SR_A   0.0   0.0        3       182       122
# 4   77.75.73.33    80  SR_A   0.0   0.0        3       182       122
#
#                                     Label  Is it Botnet?
# ...

# %%
botnetdata.to_excel("botcapture.xlsx", sheet_name='Botnet')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     315             try:
# --> 316                 self._store_workbook()
#     317             except IOError as e:
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     631         except IOError as e:
# --> 632             raise e
#     633
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     629             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 630                                 allowZip64=self.allow_zip64)
#     631         except IOError as e:
#
# ~\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
# ...

# %%
normaldata.to_excel("norcapture.xlsx", sheet_name='Normal')

# %%
sample=data[data.Proto.str.contains('udp')]
sample.head()
# Out:
#                       StartTime          Dur Proto          SrcAddr  Sport  \
# 101  2011/08/10 09:46:53.047277  3550.182373   udp    212.50.71.179  39678
# 102  2011/08/10 09:46:53.048843     0.000883   udp    84.13.246.132  28431
# 105  2011/08/10 09:46:53.053937  3427.768066   udp    74.89.223.204  21278
# 107  2011/08/10 09:46:53.058746  3589.631348   udp  182.239.167.121  49649
# 109  2011/08/10 09:46:53.062095  3118.470947   udp    24.117.206.20   8697
#
#        Dir        DstAddr  Dport State  sTos  dTos  TotPkts  TotBytes  \
# 101    <->  147.32.84.229  13363   CON   0.0   0.0       12       875
# 102    <->  147.32.84.229  13363   CON   0.0   0.0        2       135
# 105    <->  147.32.84.229  13363   CON   0.0   0.0       42      2856
# 107    <->  147.32.84.229  13363   CON   0.0   0.0       12      1494
# 109    <->  147.32.84.229  13363   CON   0.0   0.0       13      4328
#
#      SrcBytes                            Label  Is it Botnet?
# ...

# %%
sample.to_excel("sample.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-adf44d89ece8> in <module>
# ----> 1 sample.to_excel("sample.xlsx")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2179             startcol=startcol,
#    2180             freeze_panes=freeze_panes,
# -> 2181             engine=engine,
#    2182         )
#    2183
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     717         if num_rows > self.max_rows or num_cols > self.max_cols:
#     718             raise ValueError(
# --> 719                 f"This sheet is too large! Your sheet size is: {num_rows}, {num_cols} "
# ...

# %%
sample.to_csv("sample.csv")

# %%
sampledata=sample.head(10485)
sampledata.head()
# Out:
#                       StartTime          Dur Proto          SrcAddr  Sport  \
# 101  2011/08/10 09:46:53.047277  3550.182373   udp    212.50.71.179  39678
# 102  2011/08/10 09:46:53.048843     0.000883   udp    84.13.246.132  28431
# 105  2011/08/10 09:46:53.053937  3427.768066   udp    74.89.223.204  21278
# 107  2011/08/10 09:46:53.058746  3589.631348   udp  182.239.167.121  49649
# 109  2011/08/10 09:46:53.062095  3118.470947   udp    24.117.206.20   8697
#
#        Dir        DstAddr  Dport State  sTos  dTos  TotPkts  TotBytes  \
# 101    <->  147.32.84.229  13363   CON   0.0   0.0       12       875
# 102    <->  147.32.84.229  13363   CON   0.0   0.0        2       135
# 105    <->  147.32.84.229  13363   CON   0.0   0.0       42      2856
# 107    <->  147.32.84.229  13363   CON   0.0   0.0       12      1494
# 109    <->  147.32.84.229  13363   CON   0.0   0.0       13      4328
#
#      SrcBytes                            Label  Is it Botnet?
# ...

# %%
sampledata.to_excel('sample.xlsx')
